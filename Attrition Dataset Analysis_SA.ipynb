# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Importing-Libraries" data-toc-modified-id="Importing-Libraries-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Importing Libraries</a></span></li><li><span><a href="#Importing-Attrition-DataSet" data-toc-modified-id="Importing-Attrition-DataSet-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Importing Attrition DataSet</a></span></li><li><span><a href="#Checking-unique-values-in-The-DataSet" data-toc-modified-id="Checking-unique-values-in-The-DataSet-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Checking unique values in The DataSet</a></span></li><li><span><a href="#Checking-Missing-Values" data-toc-modified-id="Checking-Missing-Values-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>Checking Missing Values</a></span></li><li><span><a href="#Target-Variable-(Attrition)" data-toc-modified-id="Target-Variable-(Attrition)-0.5"><span class="toc-item-num">0.5&nbsp;&nbsp;</span>Target Variable (Attrition)</a></span><ul class="toc-item"><li><span><a href="#{1-:-Left-the-Company,-0:-Still-in-the-Company}" data-toc-modified-id="{1-:-Left-the-Company,-0:-Still-in-the-Company}-0.5.1"><span class="toc-item-num">0.5.1&nbsp;&nbsp;</span>{1 : Left the Company, 0: Still in the Company}</a></span></li></ul></li></ul></li><li><span><a href="#Count-of-Categorical-Variable" data-toc-modified-id="Count-of-Categorical-Variable-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Count of Categorical Variable</a></span><ul class="toc-item"><li><span><a href="#Distribution-of-Age" data-toc-modified-id="Distribution-of-Age-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Distribution of Age</a></span></li><li><span><a href="#Distribution-of-Monthly-Salary" data-toc-modified-id="Distribution-of-Monthly-Salary-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Distribution of Monthly Salary</a></span></li></ul></li><li><span><a href="#Gender-Analysis" data-toc-modified-id="Gender-Analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Gender Analysis</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Inference:" data-toc-modified-id="Inference:-2.0.0.1"><span class="toc-item-num">2.0.0.1&nbsp;&nbsp;</span>Inference:</a></span></li></ul></li></ul></li><li><span><a href="#Attrition-Based-on-Gender" data-toc-modified-id="Attrition-Based-on-Gender-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Attrition Based on Gender</a></span></li><li><span><a href="#Attrition-Based-on-Department" data-toc-modified-id="Attrition-Based-on-Department-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Attrition Based on Department</a></span></li></ul></li><li><span><a href="#Insights-on-the-Attrition-Rate" data-toc-modified-id="Insights-on-the-Attrition-Rate-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Insights on the Attrition Rate</a></span><ul class="toc-item"><li><span><a href="#Low-Job-Satisfaction:" data-toc-modified-id="Low-Job-Satisfaction:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Low Job Satisfaction:</a></span><ul class="toc-item"><li><span><a href="#Inferences:" data-toc-modified-id="Inferences:-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Inferences:</a></span></li></ul></li><li><span><a href="#WorkLife-Balance" data-toc-modified-id="WorkLife-Balance-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>WorkLife Balance</a></span><ul class="toc-item"><li><span><a href="#Inferences:" data-toc-modified-id="Inferences:-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Inferences:</a></span></li></ul></li><li><span><a href="#Over-Time" data-toc-modified-id="Over-Time-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Over Time</a></span><ul class="toc-item"><li><span><a href="#Inferences" data-toc-modified-id="Inferences-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Inferences</a></span></li></ul></li><li><span><a href="#Age-Vs-Attrition" data-toc-modified-id="Age-Vs-Attrition-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Age Vs Attrition</a></span><ul class="toc-item"><li><span><a href="#Inferences" data-toc-modified-id="Inferences-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Inferences</a></span></li></ul></li><li><span><a href="#Attrition-VS-Department" data-toc-modified-id="Attrition-VS-Department-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Attrition VS Department</a></span><ul class="toc-item"><li><span><a href="#Inferences" data-toc-modified-id="Inferences-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Inferences</a></span></li></ul></li><li><span><a href="#Importing-Libraries" data-toc-modified-id="Importing-Libraries-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Importing Libraries</a></span></li><li><span><a href="#Importing-Attrition-DataSet" data-toc-modified-id="Importing-Attrition-DataSet-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Importing Attrition DataSet</a></span></li><li><span><a href="#Checking-unique-values-in-The-DataSet" data-toc-modified-id="Checking-unique-values-in-The-DataSet-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Checking unique values in The DataSet</a></span></li><li><span><a href="#Checking-Missing-Values" data-toc-modified-id="Checking-Missing-Values-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Checking Missing Values</a></span></li><li><span><a href="#Target-Variable-(Attrition)" data-toc-modified-id="Target-Variable-(Attrition)-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Target Variable (Attrition)</a></span><ul class="toc-item"><li><span><a href="#{1-:-Left-the-Company,-0:-Still-in-the-Company}" data-toc-modified-id="{1-:-Left-the-Company,-0:-Still-in-the-Company}-3.10.1"><span class="toc-item-num">3.10.1&nbsp;&nbsp;</span>{1 : Left the Company, 0: Still in the Company}</a></span></li></ul></li></ul></li><li><span><a href="#Count-of-Categorical-Variable" data-toc-modified-id="Count-of-Categorical-Variable-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Count of Categorical Variable</a></span><ul class="toc-item"><li><span><a href="#Distribution-of-Age" data-toc-modified-id="Distribution-of-Age-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Distribution of Age</a></span></li><li><span><a href="#Distribution-of-Monthly-Salary" data-toc-modified-id="Distribution-of-Monthly-Salary-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Distribution of Monthly Salary</a></span></li></ul></li><li><span><a href="#Gender-Analysis" data-toc-modified-id="Gender-Analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Gender Analysis</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Inference:" data-toc-modified-id="Inference:-5.0.0.1"><span class="toc-item-num">5.0.0.1&nbsp;&nbsp;</span>Inference:</a></span></li></ul></li></ul></li><li><span><a href="#Attrition-Based-on-Gender" data-toc-modified-id="Attrition-Based-on-Gender-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Attrition Based on Gender</a></span></li><li><span><a href="#Attrition-Based-on-Department" data-toc-modified-id="Attrition-Based-on-Department-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Attrition Based on Department</a></span></li></ul></li><li><span><a href="#Insights-on-the-Attrition-Rate" data-toc-modified-id="Insights-on-the-Attrition-Rate-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Insights on the Attrition Rate</a></span><ul class="toc-item"><li><span><a href="#Low-Job-Satisfaction:" data-toc-modified-id="Low-Job-Satisfaction:-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Low Job Satisfaction:</a></span><ul class="toc-item"><li><span><a href="#Inferences:" data-toc-modified-id="Inferences:-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Inferences:</a></span></li></ul></li><li><span><a href="#WorkLife-Balance" data-toc-modified-id="WorkLife-Balance-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>WorkLife Balance</a></span><ul class="toc-item"><li><span><a href="#Inferences:" data-toc-modified-id="Inferences:-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Inferences:</a></span></li></ul></li><li><span><a href="#Over-Time" data-toc-modified-id="Over-Time-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Over Time</a></span><ul class="toc-item"><li><span><a href="#Inferences" data-toc-modified-id="Inferences-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Inferences</a></span></li></ul></li><li><span><a href="#Age-Vs-Attrition" data-toc-modified-id="Age-Vs-Attrition-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Age Vs Attrition</a></span><ul class="toc-item"><li><span><a href="#Inferences" data-toc-modified-id="Inferences-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Inferences</a></span></li></ul></li><li><span><a href="#Attrition-VS-Department" data-toc-modified-id="Attrition-VS-Department-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Attrition VS Department</a></span><ul class="toc-item"><li><span><a href="#Inferences" data-toc-modified-id="Inferences-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>Inferences</a></span></li></ul></li><li><span><a href="#Correlation-Analysis" data-toc-modified-id="Correlation-Analysis-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Correlation Analysis</a></span><ul class="toc-item"><li><span><a href="#Correlation-Inferences-:" data-toc-modified-id="Correlation-Inferences-:-6.6.1"><span class="toc-item-num">6.6.1&nbsp;&nbsp;</span>Correlation Inferences :</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# 1. Top 5 Factors
# 2. Hypothesis a) Job satisfaction b) Work Life Balance c) Over Time d)Age e)Department:

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# from sklearn.linear_model import LogisticRegression
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import r2_score, explained_variance_score, confusion_matrix, accuracy_score, classification_report, log_loss
# from math import sqrt
# from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# %matplotlib inline

#Setting the palette
sns.set_style('darkgrid')
sns.set_palette("Set3", 9)

# %% [markdown]
# ### Importing Attrition DataSet

# %%
att = pd.read_csv(r'D:\DS Study Material\T1\IML\attrition.csv')

# %%
att.head()
# Out:
#    Age  Attrition     BusinessTravel              Department EducationField  \
# 0   41          1      Travel_Rarely                   Sales  Life Sciences
# 1   49          0  Travel_Frequently  Research & Development  Life Sciences
# 2   37          1      Travel_Rarely  Research & Development          Other
# 3   33          0  Travel_Frequently  Research & Development  Life Sciences
# 4   27          0      Travel_Rarely  Research & Development        Medical
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobSatisfaction  \
# 0                        2  Female               3         2                4
# 1                        3    Male               2         2                2
# 2                        4    Male               2         1                3
# 3                        4  Female               3         1                3
# 4                        1    Male               3         1                2
#
#   MaritalStatus  MonthlyIncome OverTime  TotalWorkingYears  WorkLifeBalance  \
# 0        Single           5993      Yes                  8                1
# 1       Married           5130       No                 10                3
# 2        Single           2090      Yes                  7                3
# 3       Married           2909      Yes                  8                3
# 4       Married           3468       No                  6                3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager  DistanceFromHome
# 0                     5                 1
# 1                     7                 8
# 2                     0                 2
# 3                     0                 3
# 4                     2                 2

# %%
att.tail()
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 1465   36          0  Travel_Frequently  Research & Development
# 1466   39          0      Travel_Rarely  Research & Development
# 1467   27          0      Travel_Rarely  Research & Development
# 1468   49          0  Travel_Frequently                   Sales
# 1469   34          0      Travel_Rarely  Research & Development
#
#      EducationField  EnvironmentSatisfaction Gender  JobInvolvement  JobLevel  \
# 1465        Medical                        3   Male               4         2
# 1466        Medical                        4   Male               2         3
# 1467  Life Sciences                        2   Male               4         2
# 1468        Medical                        4   Male               2         2
# 1469        Medical                        2   Male               4         2
#
#       JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# 1465                4       Married           2571       No
# 1466                1       Married           9991       No
# 1467                2       Married           6142      Yes
# 1468                2       Married           5390       No
# 1469                3       Married           4404       No
#
#       TotalWorkingYears  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 1465                 17                3               5                   2
# 1466                  9                3               7                   7
# 1467                  6                3               6                   2
# 1468                 17                2               9                   6
# 1469                  6                4               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  DistanceFromHome
# 1465                        0                     3                23
# 1466                        1                     7                 6
# 1467                        0                     3                 4
# 1468                        0                     8                 2
# 1469                        1                     2                 8

# %%
att.describe()
# Out:
#                Age    Attrition  EnvironmentSatisfaction  JobInvolvement  \
# count  1470.000000  1470.000000              1470.000000     1470.000000
# mean     36.923810     0.161224                 2.721769        2.729932
# std       9.135373     0.367863                 1.093082        0.711561
# min      18.000000     0.000000                 1.000000        1.000000
# 25%      30.000000     0.000000                 2.000000        2.000000
# 50%      36.000000     0.000000                 3.000000        3.000000
# 75%      43.000000     0.000000                 4.000000        3.000000
# max      60.000000     1.000000                 4.000000        4.000000
#
#           JobLevel  JobSatisfaction  MonthlyIncome  TotalWorkingYears  \
# count  1470.000000      1470.000000    1470.000000        1470.000000
# mean      2.063946         2.728571    6502.931293          11.279592
# std       1.106940         1.102846    4707.956783           7.780782
# min       1.000000         1.000000    1009.000000           0.000000
# 25%       1.000000         2.000000    2911.000000           6.000000
# 50%       2.000000         3.000000    4919.000000          10.000000
# 75%       3.000000         4.000000    8379.000000          15.000000
# max       5.000000         4.000000   19999.000000          40.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  DistanceFromHome
# count              1470.000000           1470.000000       1470.000000
# mean                  2.187755              4.123129          9.192517
# std                   3.222430              3.568136          8.106864
# min                   0.000000              0.000000          1.000000
# 25%                   0.000000              2.000000          2.000000
# 50%                   1.000000              3.000000          7.000000
# 75%                   3.000000              7.000000         14.000000
# max                  15.000000             17.000000         29.000000

# %%
att.shape
# Out:
# (1470, 20)

# %% [markdown]
# <br> We have data of 1470 employees and 19 features

# %% [markdown]
# ### Checking unique values in The DataSet

# %% [markdown]
# <br> Printing the unique values if it is less than 10 otherwise just the count of unique Values

# %%
for column in att:
    unique_values = np.unique(att[column])
    unique_no = len(unique_values)
    if unique_no < 10:
        print("The number of unique values for feature {} is {} -- {}".format(column,unique_no, unique_values ))
    else:
        print("The number of unique values for feature {} is {} ".format(column,unique_no ))
# Out:
# The number of unique values for feature Age is 43
# The number of unique values for feature Attrition is 2 -- [0 1]
# The number of unique values for feature BusinessTravel is 3 -- ['Non-Travel' 'Travel_Frequently' 'Travel_Rarely']
# The number of unique values for feature Department is 3 -- ['Human Resources' 'Research & Development' 'Sales']
# The number of unique values for feature EducationField is 6 -- ['Human Resources' 'Life Sciences' 'Marketing' 'Medical' 'Other'
#  'Technical Degree']
# The number of unique values for feature EnvironmentSatisfaction is 4 -- [1 2 3 4]
# The number of unique values for feature Gender is 2 -- ['Female' 'Male']
# The number of unique values for feature JobInvolvement is 4 -- [1 2 3 4]
# The number of unique values for feature JobLevel is 5 -- [1 2 3 4 5]
# The number of unique values for feature JobSatisfaction is 4 -- [1 2 3 4]
# The number of unique values for feature MaritalStatus is 3 -- ['Divorced' 'Married' 'Single']
# The number of unique values for feature MonthlyIncome is 1349
# The number of unique values for feature OverTime is 2 -- ['No' 'Yes']
# The number of unique values for feature TotalWorkingYears is 40
# The number of unique values for feature WorkLifeBalance is 4 -- [1 2 3 4]
# The number of unique values for feature YearsAtCompany is 37
# The number of unique values for feature YearsInCurrentRole is 19
# The number of unique values for feature YearsSinceLastPromotion is 16
# The number of unique values for feature YearsWithCurrManager is 18
# The number of unique values for feature DistanceFromHome is 29

# %% [markdown]
# ### Checking Missing Values

# %%
att.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# EducationField             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobLevel                   0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# OverTime                   0
# TotalWorkingYears          0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# DistanceFromHome           0
# dtype: int64

# %% [markdown]
# <br> We have no Missing values

# %% [markdown]
# ### Target Variable (Attrition)
# #### {1 : Left the Company, 0: Still in the Company}

# %%
sns.set_style('darkgrid')
sns.countplot(x = 'Attrition', data = att, palette = 'Set3')
plt.show()
print('Percent of people who have left the company: ', round(len(att[att['Attrition'] == 1]) * 100/ len(att["Attrition"]), 2),'%')
# Out:
# Percent of people who have left the company:  16.12 %

# %% [markdown]
# ## Count of Categorical Variable

# %%
plt.figure(figsize = (15,15))
sns.set_palette("Set3")
plt.subplot(4,3,1)
sns.countplot(att.Gender)


plt.subplot(4,3,2)
sns.countplot(att.BusinessTravel)

plt.subplot(4,3,3)
sns.countplot(att.Department)

plt.subplot(4,3,4)
sns.countplot(att.EducationField)

plt.subplot(4,3,5)
sns.countplot(att.EnvironmentSatisfaction)

plt.subplot(4,3,6)
sns.countplot(att.JobInvolvement)

plt.subplot(4,3,7)
sns.countplot(att.JobLevel)

plt.subplot(4,3,8)
sns.countplot(att.JobSatisfaction)

plt.subplot(4,3,9)
sns.countplot(att.MaritalStatus)

plt.subplot(4,3,10)
sns.countplot(att.OverTime)

plt.subplot(4,3,11)
sns.countplot(att.WorkLifeBalance)

# %%
## dtype != object (int)

num = []
for column in att.columns:
    if att[column].dtype != object:
        
        #print(column)
        print(f"{column} : {att[column].unique()}")# gives unique values in each column
        print("\n")
        num.append(column)

#remove attrition from this list:
num.remove("Attrition")
num
# Out:
# Age : [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
#
#
# Attrition : [1 0]
#
#
# EnvironmentSatisfaction : [2 3 4 1]
#
#
# JobInvolvement : [3 2 4 1]
#
#
# JobLevel : [2 1 3 4 5]
#
#
# JobSatisfaction : [4 2 3 1]
#
#
# MonthlyIncome : [5993 5130 2090 ... 9991 5390 4404]
#
#
# TotalWorkingYears : [ 8 10  7  6 12  1 17  5  3 31 13  0 26 24 22  9 19  2 23 14 15  4 29 28
#  21 25 20 11 16 37 38 30 40 18 36 34 32 33 35 27]
#
#
# WorkLifeBalance : [1 3 2 4]
#
#
# YearsAtCompany : [ 6 10  0  8  2  7  1  9  5  4 25  3 12 14 22 15 27 21 17 11 13 37 16 20
#  40 24 33 19 36 18 29 31 32 34 26 30 23]
#
#
# YearsInCurrentRole : [ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
#
#
# YearsSinceLastPromotion : [ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
#
#
# YearsWithCurrManager : [ 5  7  0  2  6  8  3 11 17  1  4 12  9 10 15 13 16 14]
#
#
# DistanceFromHome : [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
# ['Age',
#  'EnvironmentSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'TotalWorkingYears',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'DistanceFromHome']

# %%
# Numerical: 

plt.figure(figsize = (20,20))
for i, column in enumerate(num, 1):
    plt.subplot(4, 4, i) # rows, cols, index
    att[att["Attrition"] == 0][column].hist(bins = 35 , label = "Attrition = 0")
    att[att["Attrition"] == 1][column].hist(bins = 35 , label = "Attrition = 1")
    plt.legend()
    plt.xlabel(column)
    
plt.savefig("NumericalVar.png", bbox_inches = "tight", dpi= 300)

# %%
## data type = object
obj = []
for column in att.columns:
    if att[column].dtype == object:
        obj.append(column)
        print(att[column].value_counts())
        print("\n")

# 06 variables -> dtype = object
## BusinessTravel, Department,EducationField,
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
#
#
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
#
#
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
#
#
# Male      882
# Female    588
# Name: Gender, dtype: int64
#
#
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64
#
#
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
#Categorical:

plt.figure(figsize = (20,20))
for i, column in enumerate(obj, 1):
    plt.subplot(4, 2, i) # rows, cols, index
    att[att["Attrition"] == 0][column].hist(bins = 35, label = "Attrition = 0")
    att[att["Attrition"] == 1][column].hist(bins = 35, label = "Attrition = 1")
    plt.legend()
    plt.xlabel(column)
    
plt.savefig("CategoricalVar.png", bbox_inches = "tight", dpi= 300)

# %% [markdown]
# ### Distribution of Age

# %%
sns.distplot(att.Age, bins=20)

# %% [markdown]
# <br> Most of the employees are between the age of 30 to 40

# %% [markdown]
# Does Age play an important part in Attrition? Do freshers leave the job or mid level people leave the job

# %% [markdown]
# ### Distribution of Monthly Salary

# %%
sns.boxplot(x = 'MonthlyIncome',data = att)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
sns.distplot(att.MonthlyIncome, kde = False)

# %% [markdown]
# <br> How many people are earning more than the extreme values?

# %% [markdown]
# ## Gender Analysis

# %% [markdown]
# What is the age distribution by Gender? Are there any discrepancies?
# Is there any gender more dissatisfied than the other?
# Is there a difference in Monthly Salaries between Gender?

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (7,8))
sns.violinplot(x='Gender', y='MonthlyIncome',hue='Attrition',split= True,data=att)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='MonthlyIncome'>

# %% [markdown]
# ##### Inference:

# %% [markdown]
# The genders weren't discriminated in income. The attrition is at the same rate in both the cases and the majority is at lower Monthly Income.

# %% [markdown]
# <br> As the data is imbalanced how do we need to take this into consideration for our analysis?

# %% [markdown]
# ### Attrition Based on Gender

# %%
sns.countplot(x = 'Attrition', hue= 'Gender', data = att, palette = 'Set3')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# ### Attrition Based on Department

# %%
sns.countplot(x = 'Attrition', hue = 'Department', data = att, palette = 'Set3')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(x = 'Department', hue = 'Attrition', data = att, palette = 'Set3')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# <br> A majority of people who have left the company are from Research and Development Department, followed by sales department. Is the manager or the functioning of the R&D Department is bad?? More analysis has to be done for the R&D Department

# %% [markdown]
# <br> Maybe the countplot is giving a wrong interpretation as the data set is imbalanced, let's try stacked bar chart and see in attrition what percentage of it is affected by other features

# %% [markdown]
# ## Insights on the Attrition Rate
# This section deals with exploring various factors which might lead to Attrition in the company, and also try to understand what might be potential causes for it.

# %% [markdown]
# Top 5 factors which we thought would affect the Attrition (Hypothesis)
# - Job satisfaction
# - Work Life Balance
# - Over Time
# - Age
# - Department

# %% [markdown]
# ### Low Job Satisfaction:
# Let's see if low job satisfaction is one of the key reasons of attrition

# %%
myData = att.copy()

# %%
myDatavsAttrition = pd.crosstab(index = myData['JobSatisfaction'] , columns  = myData['Attrition'], normalize = 'index')
# normalized by rows : so for each Job Satisfaction, it gives Proportion of Employees wrt Attrition
myDatavsAttrition.plot(kind = 'barh', stacked = True, figsize = (14,7), 
                       title = 'Job Satisfaction vs Attrition')
plt.ylabel("Proportion of Attrition")
plt.legend(loc = 'upper right')
plt.xticks(rotation= 0)
plt.savefig("Job SatisfactionVSAttrition.png",dpi=300)

# %%
# Table of proportion
myDatavsAttrition
# Out:
# Attrition               0         1
# JobSatisfaction
# 1                0.771626  0.228374
# 2                0.835714  0.164286
# 3                0.834842  0.165158
# 4                0.886710  0.113290

# %%
# Normalized on the basis of Attrition

JobSatHeat = pd.crosstab(index=myData["Attrition"],columns = myData["JobSatisfaction"],normalize='index')

ax = sns.heatmap(JobSatHeat*100, cmap="Reds",annot= True, cbar = False)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title("JobSatHeat vs Attrition")
plt.savefig("OvertimeVSAttrition.png",dpi=300)

# %% [markdown]
# #### Inferences:

# %% [markdown]
# - Employees who have low JS tend to leave more as compared to higher ratings of Job Satisfaction.
# - But all the employees who leave the job are not necessarily dissatisfied with the  job (As majority, 31% of employees, who left have marked themselves as 3/4 for Job Satisfaction)

# %%
WorkLifeBalancevsAttrition = pd.crosstab(index = myData['WorkLifeBalance'], columns  = myData['Attrition'] , normalize = 'index')
print(WorkLifeBalancevsAttrition)
WorkLifeBalancevsAttrition.plot(kind = 'barh', stacked = True, figsize = (10,7), title = 'Work Life Balance vs Attrition')
plt.ylabel("Proportion of Attrition")
plt.savefig("Work Life Balance vs Attrition.png",dpi=300)
# Out:
# Attrition               0         1
# WorkLifeBalance
# 1                0.687500  0.312500
# 2                0.831395  0.168605
# 3                0.857783  0.142217
# 4                0.823529  0.176471

# %% [markdown]
# ### WorkLife Balance

# %%
# Normalized on the basis of Attrition

JobSatHeat = pd.crosstab(index=myData["Attrition"],columns = myData["WorkLifeBalance"],normalize='index')

ax = sns.heatmap(JobSatHeat*100, cmap="Reds",annot= True, cbar = False)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title("WorkLifeBalance vs Attrition")
plt.savefig("Work Life Balance vs Attrition heat.png",dpi=300)

# %% [markdown]
# #### Inferences:

# %% [markdown]
# - Employees who have poor worklife Balance have left the company

# %% [markdown]
# ### Over Time

# %%
OverTimevsAttrition = pd.crosstab(index = myData['Attrition'] , columns  = myData['OverTime'], normalize = 'index')

OverTimevsAttrition.plot(kind = 'barh', stacked = True, figsize = (10,7), title = 'OverTime vs Attrition', ylabel = 'Percentage of Attrition')
plt.savefig("Over Time vs Attrition.png",dpi=300)

# %%
OvertimeVSattrition = pd.crosstab(index=myData["Attrition"],columns = myData["OverTime"],normalize='index')

ax = sns.heatmap(OvertimeVSattrition*100, cmap="Reds",annot= True, cbar = False)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title("Overtime vs Attrition")
#plt.savefig("OvertimeVSAttrition.png",bbox_inches='tight',dpi=300)
# Out:
# Text(0.5, 1.0, 'Overtime vs Attrition')

# %%
OvertimeVSattrition = pd.crosstab(index=myData["Attrition"],columns = myData["OverTime"],normalize='columns')

ax = sns.heatmap(OvertimeVSattrition*100, cmap = 'Reds',annot= True, cbar = False)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title("Overtime vs Attrition")
#plt.savefig("OvertimeVSAttrition.png",bbox_inches='tight',dpi=300)
# Out:
# Text(0.5, 1.0, 'Overtime vs Attrition')

# %% [markdown]
# #### Inferences

# %% [markdown]
# - Employee who have left the company have worked more overtime as compared to people who haven't

# %% [markdown]
# ### Age Vs Attrition

# %%
myData["Age_Group"] = ""
myData.loc[myData["Age"].between(18,24),"Age_Group"] = "18-24"
myData.loc[myData["Age"].between(25,31),"Age_Group"] = "25-31"
myData.loc[myData["Age"].between(32,38),"Age_Group"] = "32-38"
myData.loc[myData["Age"].between(39,45),"Age_Group"] = "39-45"
myData.loc[myData["Age"].between(46,52),"Age_Group"] = "46-52"
myData.loc[myData["Age"] >= 53,"Age_Group"] = ">=53"


ageGroupsVSattrition = pd.crosstab(index=myData["Age_Group"],
                                   columns=myData["Attrition"],
                                   normalize= "index"
                                  )

ageGroupsVSattrition.sort_values('Age_Group',inplace=True, ascending = False)
ageGroupsVSattrition.plot(kind="barh",stacked=True,figsize = (16,8), legend = False, xlabel = 'Age Group', ylabel = '% Attrition')
plt.legend(loc = 'upper right')
plt.title('Age Group VS Attrition')
plt.xticks(rotation= 0)
plt.savefig("AgeGroupVSAttritionH.png",dpi=300)

# %% [markdown]
# #### Inferences

# %% [markdown]
# - The Age does play a major impact on the attrition, the highest among any other factor
# - Though this is quite normal as for higher packages employee do switch jobs in the beginning of their career.

# %% [markdown]
# ### Attrition VS Department

# %% [markdown]
# - This is to check,if employees who were trained for a required field, by education, do indeed pursue a work in that field or not ? And if not does it lead to eventually quitting the job for a different job ?

# %%
myData["DiffField"] = 'Yes' # Creating and Initializing Different Fields as YES

# If Education Field and the Department is same then changing the value of the Different Field Column to No
myData.loc[(myData["EducationField"].isin(['Life Sciences','Medical','Technical Degree']) &
           (myData["Department"] == 'Research & Development')), "DiffField"] = 'No'
myData.loc[(myData["EducationField"].isin(["Marketing"]) & 
           (myData["Department"] == 'Sales')),"DiffField"] = 'No'
myData.loc[(myData["EducationField"].isin(["Human Resources"]) &
           (myData["Department"] == 'Human Resources')),"DiffField"] = 'No'
myDataVSattrition = pd.crosstab(index=myData["DiffField"],columns = myData["Attrition"],normalize="index")
myDataVSdept = pd.crosstab(index=myData["Department"],columns = myData["DiffField"],normalize="index")

fig,ax = plt.subplots(1,2,figsize=(16,8))
myDataVSdept.plot(kind='barh',stacked=True,ax=ax[0])
ax[0].set_title("DiffField across Departments")
myDataVSattrition.plot(kind='bar',stacked=True,ax=ax[1])
ax[1].set_title("DiffField against Attrition")

plt.savefig("DiffEduFieldVSAttrition.png",bbox_inches = "tight",dpi=300)

# %% [markdown]
# #### Inferences

# %% [markdown]
# - For R&D department, Only 6% of employees claim to be from different educational background than required by the job.
# - 57% of employees in HR and 64% of employees in Sales, were trained in a different educational stream than what is required by the Job.
# - Off all the employees who belonged to this category only 18% of them left the job, this means that its not an important predictor for Attrition.

# %% [markdown]
# 1. Top 5 Factors
# 2. Hypothesis a) Job satisfaction b) Work Life Balance c) Over Time d)Age e)Department:

# %% [markdown]
# Actual Affecting: Overtime, Joblevel, AgeGroup,

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, explained_variance_score, confusion_matrix, accuracy_score, classification_report, log_loss
from math import sqrt
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
# %matplotlib inline

#Setting the palette
sns.set_style('darkgrid')
sns.set_palette("hls", 9)

# %% [markdown]
# ### Importing Attrition DataSet

# %%
att = pd.read_csv(r'C:\Users\Chief\Documents\Praxis\Term 1\IML\Attrition\attrition.csv')

# %%
att.head()
# Out:
#    Age  Attrition     BusinessTravel              Department EducationField  \
# 0   41          1      Travel_Rarely                   Sales  Life Sciences
# 1   49          0  Travel_Frequently  Research & Development  Life Sciences
# 2   37          1      Travel_Rarely  Research & Development          Other
# 3   33          0  Travel_Frequently  Research & Development  Life Sciences
# 4   27          0      Travel_Rarely  Research & Development        Medical
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobSatisfaction  \
# 0                        2  Female               3         2                4
# 1                        3    Male               2         2                2
# 2                        4    Male               2         1                3
# 3                        4  Female               3         1                3
# 4                        1    Male               3         1                2
#
#   MaritalStatus  MonthlyIncome OverTime  TotalWorkingYears  WorkLifeBalance  \
# 0        Single           5993      Yes                  8                1
# 1       Married           5130       No                 10                3
# 2        Single           2090      Yes                  7                3
# 3       Married           2909      Yes                  8                3
# 4       Married           3468       No                  6                3
#
#    YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               6                   4                        0
# 1              10                   7                        1
# 2               0                   0                        0
# 3               8                   7                        3
# 4               2                   2                        2
#
#    YearsWithCurrManager  DistanceFromHome
# 0                     5                 1
# 1                     7                 8
# 2                     0                 2
# 3                     0                 3
# 4                     2                 2

# %%
att.tail()
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 1465   36          0  Travel_Frequently  Research & Development
# 1466   39          0      Travel_Rarely  Research & Development
# 1467   27          0      Travel_Rarely  Research & Development
# 1468   49          0  Travel_Frequently                   Sales
# 1469   34          0      Travel_Rarely  Research & Development
#
#      EducationField  EnvironmentSatisfaction Gender  JobInvolvement  JobLevel  \
# 1465        Medical                        3   Male               4         2
# 1466        Medical                        4   Male               2         3
# 1467  Life Sciences                        2   Male               4         2
# 1468        Medical                        4   Male               2         2
# 1469        Medical                        2   Male               4         2
#
#       JobSatisfaction MaritalStatus  MonthlyIncome OverTime  \
# 1465                4       Married           2571       No
# 1466                1       Married           9991       No
# 1467                2       Married           6142      Yes
# 1468                2       Married           5390       No
# 1469                3       Married           4404       No
#
#       TotalWorkingYears  WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 1465                 17                3               5                   2
# 1466                  9                3               7                   7
# 1467                  6                3               6                   2
# 1468                 17                2               9                   6
# 1469                  6                4               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  DistanceFromHome
# 1465                        0                     3                23
# 1466                        1                     7                 6
# 1467                        0                     3                 4
# 1468                        0                     8                 2
# 1469                        1                     2                 8

# %%
att.describe()
# Out:
#                Age    Attrition  EnvironmentSatisfaction  JobInvolvement  \
# count  1470.000000  1470.000000              1470.000000     1470.000000
# mean     36.923810     0.161224                 2.721769        2.729932
# std       9.135373     0.367863                 1.093082        0.711561
# min      18.000000     0.000000                 1.000000        1.000000
# 25%      30.000000     0.000000                 2.000000        2.000000
# 50%      36.000000     0.000000                 3.000000        3.000000
# 75%      43.000000     0.000000                 4.000000        3.000000
# max      60.000000     1.000000                 4.000000        4.000000
#
#           JobLevel  JobSatisfaction  MonthlyIncome  TotalWorkingYears  \
# count  1470.000000      1470.000000    1470.000000        1470.000000
# mean      2.063946         2.728571    6502.931293          11.279592
# std       1.106940         1.102846    4707.956783           7.780782
# min       1.000000         1.000000    1009.000000           0.000000
# 25%       1.000000         2.000000    2911.000000           6.000000
# 50%       2.000000         3.000000    4919.000000          10.000000
# 75%       3.000000         4.000000    8379.000000          15.000000
# max       5.000000         4.000000   19999.000000          40.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1470.000000     1470.000000         1470.000000
# mean          2.761224        7.008163            4.229252
# std           0.706476        6.126525            3.623137
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  DistanceFromHome
# count              1470.000000           1470.000000       1470.000000
# mean                  2.187755              4.123129          9.192517
# std                   3.222430              3.568136          8.106864
# min                   0.000000              0.000000          1.000000
# 25%                   0.000000              2.000000          2.000000
# 50%                   1.000000              3.000000          7.000000
# 75%                   3.000000              7.000000         14.000000
# max                  15.000000             17.000000         29.000000

# %%
att.shape
# Out:
# (1470, 20)

# %% [markdown]
# <br> We have data of 1470 employees and 19 features

# %% [markdown]
# ### Checking unique values in The DataSet

# %% [markdown]
# <br> Printing the unique values if it is less than 10 otherwise just the count of unique Values

# %%
for column in att:
    unique_values = np.unique(att[column])
    unique_no = len(unique_values)
    if unique_no < 10:
        print("The number of unique values for feature {} is {} -- {}".format(column,unique_no, unique_values ))
    else:
        print("The number of unique values for feature {} is {} ".format(column,unique_no ))
# Out:
# The number of unique values for feature Age is 43
# The number of unique values for feature Attrition is 2 -- [0 1]
# The number of unique values for feature BusinessTravel is 3 -- ['Non-Travel' 'Travel_Frequently' 'Travel_Rarely']
# The number of unique values for feature Department is 3 -- ['Human Resources' 'Research & Development' 'Sales']
# The number of unique values for feature EducationField is 6 -- ['Human Resources' 'Life Sciences' 'Marketing' 'Medical' 'Other'
#  'Technical Degree']
# The number of unique values for feature EnvironmentSatisfaction is 4 -- [1 2 3 4]
# The number of unique values for feature Gender is 2 -- ['Female' 'Male']
# The number of unique values for feature JobInvolvement is 4 -- [1 2 3 4]
# The number of unique values for feature JobLevel is 5 -- [1 2 3 4 5]
# The number of unique values for feature JobSatisfaction is 4 -- [1 2 3 4]
# The number of unique values for feature MaritalStatus is 3 -- ['Divorced' 'Married' 'Single']
# The number of unique values for feature MonthlyIncome is 1349
# The number of unique values for feature OverTime is 2 -- ['No' 'Yes']
# The number of unique values for feature TotalWorkingYears is 40
# The number of unique values for feature WorkLifeBalance is 4 -- [1 2 3 4]
# The number of unique values for feature YearsAtCompany is 37
# The number of unique values for feature YearsInCurrentRole is 19
# The number of unique values for feature YearsSinceLastPromotion is 16
# The number of unique values for feature YearsWithCurrManager is 18
# The number of unique values for feature DistanceFromHome is 29

# %% [markdown]
# ### Checking Missing Values

# %%
att.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# EducationField             0
# EnvironmentSatisfaction    0
# Gender                     0
# JobInvolvement             0
# JobLevel                   0
# JobSatisfaction            0
# MaritalStatus              0
# MonthlyIncome              0
# OverTime                   0
# TotalWorkingYears          0
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# DistanceFromHome           0
# dtype: int64

# %% [markdown]
# <br> We have no Missing values

# %% [markdown]
# ### Target Variable (Attrition)
# #### {1 : Left the Company, 0: Still in the Company}

# %%
sns.set_style('darkgrid')
sns.countplot(x = 'Attrition', data = att, palette = 'Set3')
plt.show()
print('Percent of people who have left the company: ', round(len(att[att['Attrition'] == 1]) * 100/ len(att["Attrition"]), 2),'%')
# Out:
# Percent of people who have left the company:  16.12 %

# %% [markdown]
# ## Count of Categorical Variable

# %%
plt.figure(figsize = (15,15))
sns.set_palette("Set3")
plt.subplot(4,3,1)
sns.countplot(att.Gender)


plt.subplot(4,3,2)
sns.countplot(att.BusinessTravel)

plt.subplot(4,3,3)
sns.countplot(att.Department)

plt.subplot(4,3,4)
sns.countplot(att.EducationField)

plt.subplot(4,3,5)
sns.countplot(att.EnvironmentSatisfaction)

plt.subplot(4,3,6)
sns.countplot(att.JobInvolvement)

plt.subplot(4,3,7)
sns.countplot(att.JobLevel)

plt.subplot(4,3,8)
sns.countplot(att.JobSatisfaction)

plt.subplot(4,3,9)
sns.countplot(att.MaritalStatus)

plt.subplot(4,3,10)
sns.countplot(att.OverTime)

plt.subplot(4,3,11)
sns.countplot(att.WorkLifeBalance)
# Out:
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='count'>

# %% [markdown]
# ### Distribution of Age

# %%
sns.displot(att, x= att.Age, bins=20)

# %% [markdown]
# <br> Most of the employees are between the age of 30 to 40

# %% [markdown]
# Does Age play an important part in Attrition? Do freshers leave the job or mid level people leave the job

# %% [markdown]
# ### Distribution of Monthly Salary

# %%
sns.boxplot(x = 'MonthlyIncome',data = att)
# Out:
# <AxesSubplot:xlabel='MonthlyIncome'>

# %%
sns.distplot(att.MonthlyIncome, kde = False)
# Out:
# C:\Users\Chief\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MonthlyIncome'>

# %% [markdown]
# <br> How many people are earning more than the extreme values?

# %% [markdown]
# ## Gender Analysis

# %% [markdown]
# What is the age distribution by Gender? Are there any discrepancies?
# Is there any gender more disatisfied than the other?
# Is there a difference in Monthly Salaries between Gender?

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (7,8))
sns.violinplot(x='Gender', y='MonthlyIncome',hue='Attrition',split= True,data=att)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='MonthlyIncome'>

# %% [markdown]
# ##### Inference:

# %% [markdown]
# The genders weren't discriminated in income. The attrition is at the same rate in both the cases and the majority is at lower Monthly Income.

# %% [markdown]
# <br> As the data is imbalanced how do we need to take this into consideration for our analysis?

# %% [markdown]
# ### Attrition Based on Gender

# %%
sns.countplot(x = 'Attrition', hue= 'Gender', data = att, palette = 'Set3')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# ### Attrition Based on Department

# %%
sns.countplot(x = 'Attrition', hue = 'Department', data = att, palette = 'Set3')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.countplot(x = 'Department', hue = 'Attrition', data = att, palette = 'Set3')
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# <br> A majority of people who have left the company are from Research and Development Department, followed by sales department. Is the manager or the functioning of the R&D Department is bad?? More analysis has to be done for the R&D Department

# %% [markdown]
# <br> Maybe the countplot is giving a wrong interpretation as the data set is imbalanced, let's try stacked bar chart and see in attrition what percentage of it is affected by other features

# %% [markdown]
# ## Insights on the Attrition Rate
# This section deals with exploring various factors which might lead to Attrition in the company, and also try to understand what might be potential causes for it.

# %% [markdown]
# Top 5 factors which we thought would affect the Attrition (Hypothesis)
# - Job satisfaction
# - Work Life Balance
# - Over Time
# - Age
# - Department

# %% [markdown]
# ### Low Job Satisfaction:
# Let's see if low job satisfaction is one of the key reasons of attrition

# %%
myData = att.copy()

# %%
myDatavsAttrition = pd.crosstab(index = myData['JobSatisfaction'] , columns  = myData['Attrition'], normalize = 'index')
myDatavsAttrition.plot(kind = 'barh', stacked = True, figsize = (14,7), title = 'Job Satisfaction vs Attrition')
plt.xlabel("Proportion of Attrition")
plt.legend(loc = 'upper right')
plt.xticks(rotation= 0)
#plt.savefig("Job SatisfactionVSAttrition.png",dpi=300)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  <a list of 7 Text major ticklabel objects>)

# %%
# Normalized on the basis of Attrition

JobSatHeat = pd.crosstab(index=myData["Attrition"],columns = myData["JobSatisfaction"],normalize='index')
plt.xlabel("Proportion of Attrition")
ax = sns.heatmap(JobSatHeat*100, cmap="Reds",annot= True, cbar = False)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title("JobSatHeat vs Attrition")
#plt.savefig("OvertimeVSAttrition.png",dpi=300)
# Out:
# Text(0.5, 1.0, 'JobSatHeat vs Attrition')

# %%
# Normalized on the basis of Attrition

JobSatHeat = pd.crosstab(index=myData["Attrition"],columns = myData["JobSatisfaction"],normalize='columns')

ax = sns.heatmap(JobSatHeat*100, cmap="Reds",annot= True, cbar = False, square = True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title("JobSatHeat vs Attrition")
#plt.savefig("OvertimeVSAttrition.png",bbox_inches='tight',dpi=300)
# Out:
# Text(0.5, 1.0, 'JobSatHeat vs Attrition')

# %% [markdown]
# #### Inferences:

# %% [markdown]
# - Employees who have low JS tends to leave more as compared to higher ratings.
# - But employee who leave the job are not necessarily disastisfied with the  job.

# %% [markdown]
# ### WorkLife Balance

# %%
WorkLifeBalancevsAttrition = pd.crosstab(index = myData['WorkLifeBalance'], columns  = myData['Attrition'] , normalize = 'index')
print(WorkLifeBalancevsAttrition)
WorkLifeBalancevsAttrition.plot(kind = 'barh', stacked = True, figsize = (10,7), title = 'Work Life Balance vs Attrition')
plt.xlabel("Proportion of Attrition")
#plt.savefig("Work Life Balance vs Attrition.png",dpi=300)
# Out:
# Attrition               0         1
# WorkLifeBalance
# 1                0.687500  0.312500
# 2                0.831395  0.168605
# 3                0.857783  0.142217
# 4                0.823529  0.176471
# Text(0.5, 0, 'Proportion of Attrition')

# %%
# Normalized on the basis of Attrition

JobSatHeat = pd.crosstab(index=myData["Attrition"],columns = myData["WorkLifeBalance"],normalize='index')

ax = sns.heatmap(JobSatHeat*100, cmap="Reds",annot= True, cbar = False)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title("WorkLifeBalance vs Attrition")
#plt.savefig("Work Life Balance vs Attrition heat.png",dpi=300)

# %% [markdown]
# #### Inferences:

# %% [markdown]
# - Employees who have lower(1-2) Job Work Life Balance have a higher tendency to leave the job compare to those employees who dont complain of Work Life Balance.
# - So Work Life Balance rating is a good predictor of Attrition.
# - But on the contrary, it is also important to note that employees who left the job do not necessary have poor Work Life Balance. ( As majority, 54% of employees, who left have marked themselves as 3/4 for Work Life Balance)

# %% [markdown]
# ### Over Time

# %%
OverTimevsAttrition = pd.crosstab(index = myData['Attrition'] , columns  = myData['OverTime'], normalize = 'index')
print(OverTimevsAttrition)
OverTimevsAttrition.plot(kind = 'barh', stacked = True, figsize = (10,7), title = 'OverTime vs Attrition')
plt.xlabel("Proportion of Attrition")
#plt.savefig("Over Time vs Attrition.png",dpi=300)
# Out:
# OverTime         No       Yes
# Attrition
# 0          0.765612  0.234388
# 1          0.464135  0.535865
# Text(0.5, 0, 'Proportion of Attrition')

# %%
OvertimeVSattrition = pd.crosstab(index=myData["Attrition"],columns = myData["OverTime"],normalize='index')

ax = sns.heatmap(OvertimeVSattrition*100, cmap="Reds",annot= True, cbar = False)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title("Overtime vs Attrition")
#plt.savefig("OvertimeVSAttrition.png",bbox_inches='tight',dpi=300)
# Out:
# Text(0.5, 1.0, 'Overtime vs Attrition')

# %%
# Normalized on OverTime Rating
OvertimeVSattrition = pd.crosstab(index=myData["Attrition"],columns = myData["OverTime"],normalize='columns')

ax = sns.heatmap(OvertimeVSattrition*100, cmap = 'Reds',annot= True, cbar = False)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.title("Overtime vs Attrition")
#plt.savefig("OvertimeVSAttrition.png",bbox_inches='tight',dpi=300)
# Out:
# Text(0.5, 1.0, 'Overtime vs Attrition')

# %% [markdown]
# #### Inferences

# %% [markdown]
# - Employee who have left the company have worked more overtime as compared to people who haven't.

# %% [markdown]
# ### Age Vs Attrition

# %%
myData["Age_Group"] = ""
myData.loc[myData["Age"].between(18,24),"Age_Group"] = "18-24"
myData.loc[myData["Age"].between(25,31),"Age_Group"] = "25-31"
myData.loc[myData["Age"].between(32,38),"Age_Group"] = "32-38"
myData.loc[myData["Age"].between(39,45),"Age_Group"] = "39-45"
myData.loc[myData["Age"].between(46,52),"Age_Group"] = "46-52"
myData.loc[myData["Age"] >= 53,"Age_Group"] = ">=53"


ageGroupsVSattrition = pd.crosstab(index=myData["Age_Group"],
                                   columns=myData["Attrition"],
                                   normalize= "index"
                                  )

ageGroupsVSattrition.sort_values('Age_Group',inplace=True, ascending = False)
ageGroupsVSattrition.plot(kind="barh",stacked=True,figsize = (16,8), legend = False)
#plt.ylabel("Age Group")
plt.xlabel("Proportion of Attrition")
plt.legend(loc = 'upper right')
plt.title('Age Group VS Attrition')
plt.xticks(rotation= 0)
#plt.savefig("AgeGroupVSAttritionH.png",dpi=300)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  <a list of 7 Text major ticklabel objects>)

# %% [markdown]
# #### Inferences

# %% [markdown]
# - The Age does play a major impact on the attrition, the highest among any other factor
# - Though this is quite normal as for higher packages employee do switch jobs in the beginning of their career.

# %% [markdown]
# ### Attrition VS Department

# %% [markdown]
# - This is to check,if employees who were trained for a required field, by education, do indeed pursue a work in that field or not ? And if not does it lead to eventually quitting the job for a different job ?

# %%
myData["DiffField"] = 'Yes' # Creating and Initializing Different Fields as YES

# If Education Field and the Department is same then changing the value of the Different Field Column to No
myData.loc[(myData["EducationField"].isin(['Life Sciences','Medical','Technical Degree']) &
           (myData["Department"] == 'Research & Development')), "DiffField"] = 'No'
myData.loc[(myData["EducationField"].isin(["Marketing"]) & 
           (myData["Department"] == 'Sales')),"DiffField"] = 'No'
myData.loc[(myData["EducationField"].isin(["Human Resources"]) &
           (myData["Department"] == 'Human Resources')),"DiffField"] = 'No'
myDataVSattrition = pd.crosstab(index=myData["DiffField"],columns = myData["Attrition"],normalize="index")
myDataVSdept = pd.crosstab(index=myData["Department"],columns = myData["DiffField"],normalize="index")
print("Different Fields")
print(myDataVSdept)
print("\n")
print("Attrition vs Different Fields")
print(myDataVSattrition)
fig,ax = plt.subplots(1,2,figsize=(16,8))
myDataVSdept.plot(kind='barh',stacked=True,ax=ax[0])
ax[0].set_title("DiffField across Departments")
myDataVSattrition.plot(kind='bar',stacked=True,ax=ax[1])
ax[1].set_title("DiffField against Attrition")

#plt.savefig("DiffEduFieldVSAttrition.png",bbox_inches = "tight",dpi=300)
# Out:
# Different Fields
# DiffField                     No       Yes
# Department
# Human Resources         0.428571  0.571429
# Research & Development  0.933403  0.066597
# Sales                   0.356502  0.643498
#
#
# Attrition vs Different Fields
# Attrition         0         1
# DiffField
# No         0.844875  0.155125
# Yes        0.821705  0.178295
# Text(0.5, 1.0, 'DiffField against Attrition')

# %% [markdown]
# #### Inferences

# %% [markdown]
# - For R&D department, Only 6% of employees claim to be from different educational background than required by the job.
# - 57% of employees in HR and 64% of employees in Sales, were trained in a different educational stream than what is required by the Job.
# - Off all the employees who belonged to this category only ~18% of them left the job, this means that its not an important predictor for Attrition.

# %% [markdown]
# ### Correlation Analysis

# %%
# Transform categorical data into dummies
dummy_col = ['BusinessTravel',
 'Department',
 'EducationField',
 'EnvironmentSatisfaction',
 'Gender',
 'JobInvolvement',
 'JobLevel',
 'JobSatisfaction',
 'MaritalStatus',
 'OverTime',
 'WorkLifeBalance',
 'YearsInCurrentRole',
 'YearsSinceLastPromotion',
 'YearsWithCurrManager']
#type(dummy_col)

att_dummy = pd.get_dummies(att, columns = dummy_col,dtype = "uint8") #uint8 => dtype for categorical variables

att_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 99 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1470 non-null   int64
#  1   Attrition                          1470 non-null   int64
#  2   MonthlyIncome                      1470 non-null   int64
#  3   TotalWorkingYears                  1470 non-null   int64
#  4   YearsAtCompany                     1470 non-null   int64
#  5   DistanceFromHome                   1470 non-null   int64
#  6   BusinessTravel_Non-Travel          1470 non-null   uint8
#  7   BusinessTravel_Travel_Frequently   1470 non-null   uint8
#  8   BusinessTravel_Travel_Rarely       1470 non-null   uint8
#  9   Department_Human Resources         1470 non-null   uint8
#  10  Department_Research & Development  1470 non-null   uint8
#  11  Department_Sales                   1470 non-null   uint8
#  12  EducationField_Human Resources     1470 non-null   uint8
#  13  EducationField_Life Sciences       1470 non-null   uint8
#  14  EducationField_Marketing           1470 non-null   uint8
#  15  EducationField_Medical             1470 non-null   uint8
#  16  EducationField_Other               1470 non-null   uint8
#  17  EducationField_Technical Degree    1470 non-null   uint8
#  18  EnvironmentSatisfaction_1          1470 non-null   uint8
#  19  EnvironmentSatisfaction_2          1470 non-null   uint8
#  20  EnvironmentSatisfaction_3          1470 non-null   uint8
#  21  EnvironmentSatisfaction_4          1470 non-null   uint8
#  22  Gender_Female                      1470 non-null   uint8
#  23  Gender_Male                        1470 non-null   uint8
#  24  JobInvolvement_1                   1470 non-null   uint8
#  25  JobInvolvement_2                   1470 non-null   uint8
#  26  JobInvolvement_3                   1470 non-null   uint8
#  27  JobInvolvement_4                   1470 non-null   uint8
#  28  JobLevel_1                         1470 non-null   uint8
#  29  JobLevel_2                         1470 non-null   uint8
#  30  JobLevel_3                         1470 non-null   uint8
#  31  JobLevel_4                         1470 non-null   uint8
#  32  JobLevel_5                         1470 non-null   uint8
#  33  JobSatisfaction_1                  1470 non-null   uint8
#  34  JobSatisfaction_2                  1470 non-null   uint8
#  35  JobSatisfaction_3                  1470 non-null   uint8
#  36  JobSatisfaction_4                  1470 non-null   uint8
#  37  MaritalStatus_Divorced             1470 non-null   uint8
#  38  MaritalStatus_Married              1470 non-null   uint8
#  39  MaritalStatus_Single               1470 non-null   uint8
#  40  OverTime_No                        1470 non-null   uint8
#  41  OverTime_Yes                       1470 non-null   uint8
#  42  WorkLifeBalance_1                  1470 non-null   uint8
#  43  WorkLifeBalance_2                  1470 non-null   uint8
#  44  WorkLifeBalance_3                  1470 non-null   uint8
#  45  WorkLifeBalance_4                  1470 non-null   uint8
#  46  YearsInCurrentRole_0               1470 non-null   uint8
#  47  YearsInCurrentRole_1               1470 non-null   uint8
#  48  YearsInCurrentRole_2               1470 non-null   uint8
#  49  YearsInCurrentRole_3               1470 non-null   uint8
#  50  YearsInCurrentRole_4               1470 non-null   uint8
#  51  YearsInCurrentRole_5               1470 non-null   uint8
#  52  YearsInCurrentRole_6               1470 non-null   uint8
#  53  YearsInCurrentRole_7               1470 non-null   uint8
#  54  YearsInCurrentRole_8               1470 non-null   uint8
#  55  YearsInCurrentRole_9               1470 non-null   uint8
#  56  YearsInCurrentRole_10              1470 non-null   uint8
#  57  YearsInCurrentRole_11              1470 non-null   uint8
#  58  YearsInCurrentRole_12              1470 non-null   uint8
#  59  YearsInCurrentRole_13              1470 non-null   uint8
#  60  YearsInCurrentRole_14              1470 non-null   uint8
#  61  YearsInCurrentRole_15              1470 non-null   uint8
#  62  YearsInCurrentRole_16              1470 non-null   uint8
#  63  YearsInCurrentRole_17              1470 non-null   uint8
#  64  YearsInCurrentRole_18              1470 non-null   uint8
#  65  YearsSinceLastPromotion_0          1470 non-null   uint8
#  66  YearsSinceLastPromotion_1          1470 non-null   uint8
#  67  YearsSinceLastPromotion_2          1470 non-null   uint8
#  68  YearsSinceLastPromotion_3          1470 non-null   uint8
#  69  YearsSinceLastPromotion_4          1470 non-null   uint8
#  70  YearsSinceLastPromotion_5          1470 non-null   uint8
#  71  YearsSinceLastPromotion_6          1470 non-null   uint8
#  72  YearsSinceLastPromotion_7          1470 non-null   uint8
#  73  YearsSinceLastPromotion_8          1470 non-null   uint8
#  74  YearsSinceLastPromotion_9          1470 non-null   uint8
#  75  YearsSinceLastPromotion_10         1470 non-null   uint8
#  76  YearsSinceLastPromotion_11         1470 non-null   uint8
#  77  YearsSinceLastPromotion_12         1470 non-null   uint8
#  78  YearsSinceLastPromotion_13         1470 non-null   uint8
#  79  YearsSinceLastPromotion_14         1470 non-null   uint8
#  80  YearsSinceLastPromotion_15         1470 non-null   uint8
#  81  YearsWithCurrManager_0             1470 non-null   uint8
#  82  YearsWithCurrManager_1             1470 non-null   uint8
#  83  YearsWithCurrManager_2             1470 non-null   uint8
#  84  YearsWithCurrManager_3             1470 non-null   uint8
#  85  YearsWithCurrManager_4             1470 non-null   uint8
#  86  YearsWithCurrManager_5             1470 non-null   uint8
#  87  YearsWithCurrManager_6             1470 non-null   uint8
#  88  YearsWithCurrManager_7             1470 non-null   uint8
#  89  YearsWithCurrManager_8             1470 non-null   uint8
#  90  YearsWithCurrManager_9             1470 non-null   uint8
#  91  YearsWithCurrManager_10            1470 non-null   uint8
#  92  YearsWithCurrManager_11            1470 non-null   uint8
#  93  YearsWithCurrManager_12            1470 non-null   uint8
#  94  YearsWithCurrManager_13            1470 non-null   uint8
#  95  YearsWithCurrManager_14            1470 non-null   uint8
#  96  YearsWithCurrManager_15            1470 non-null   uint8
#  97  YearsWithCurrManager_16            1470 non-null   uint8
#  98  YearsWithCurrManager_17            1470 non-null   uint8
# dtypes: int64(6), uint8(93)
# memory usage: 202.5 KB

# %%
att_dummy.drop("Attrition", axis =1).corrwith(att.Attrition).sort_values().plot(kind = "barh", figsize= (15,30))

## overtime_yes, job level_1, yearswithcurrmanager_0, maritalstatus_Single, yearsInCurrentRole_0
## bottom 5 : Overtime_No, TotalWorkingYears, MonthlyIncome, Age, YearsAtCompany

#plt.savefig("Correlation_allvar.png", bbox_inches = "tight", dpi= 300)

# %% [markdown]
# #### Correlation Inferences :
# - Individually none of the variables show a significant Correlation with Attrition as all the values of Correlation is between -0.2 to 0.2 ( Uncorrelated )
# - When ordered based on Correlation Values, the top features which have the highest correlation are :
#
# a) Overtime ( Yes ) : People who work OverTime
#
# b) JobLevel ( 1 ) : People who are junior-most (younger section) in the company
#
# c) YearsWithCurrManager(0) : People who are junior and includes those whose manager changed recently and then they didn't like their leadership
#
# d) Marital Status (Single) : Includes the younger employees
#
# e) YearsInCurrentRole(0) : Includes the younger Employees and employees who have switched roles
#
# This is followed by Lower Environment Satisfaction,Job Involvement, Work Life Balance and Job Satisfaction.
